# %%
a=10
b=20
if a>b:
    print(f"{a} is greaterthen {b}")
    print("Hello")

else:
    print(f"{b} is greaterthen {a}")
    print("Hello Madhu")

# %%
x=input("please enter your name")
print(f"your name is {x}")

# %%
a=int(input("Please enter your marks"))
type(a)
if a>90:
    print("You are first class student")
elif a>70:
    print("You are second class student")
else:
    print("You are third class student")
