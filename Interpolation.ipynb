# %%
X=10
Y="Madhu"

# %%
print(X,Y)

# %%
print("Hello "+Y+ " your age is "+str(X))

# %%
print("Hello %s your age is %s" %(Y,str(X)))

# %%
print("Hello {} your age is {}".format(Y,X))
print("Hello {a1} your age is {b1}".format(a1=Y,b1=X))
print(f"Hello {Y} your age is {X}")

# %%
print(f"Hello guys this is {Y}, and my age is {str(X)}")
