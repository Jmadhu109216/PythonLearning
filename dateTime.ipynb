# %%
dir()

# %%
import datetime
# dir()
date1=datetime.datetime.now()
print(date1)

# %%
date2=datetime.datetime.today()
print(date2)
date3=datetime.datetime.now().strftime("%Y-%m-%d")
print(date3)

print(date2.year)
print(date2.month)
print(date2.day)
print(date2.hour)
print(date2.minute)
print(date2.second)

# %%
date5=datetime.date.day()
print(date5)

# %%
# help(datetime.datetime)
date6=datetime.datetime(2025,9,3,11,45,0)
print(date6)

# %%
# help(datetime.time)
date7=datetime.time(20,10,10,00)
print(date7)

type(date7)

# %%
print(datetime.timedelta(days=1))
print(datetime.timedelta(hours=1))
print(datetime.timedelta(minutes=1))
date8=datetime.timedelta(days=20,hours=5,minutes=50)
date8=datetime.timedelta(days=19,hours=5,minutes=50)
date7-date8

# %%
d1=datetime.datetime(2025,9,3,11,45,0)
d2=datetime.datetime(2000,1,20,4,30,50)
birth=d1-d2
print(birth.days)
print(birth.days/365)
type(birth)
